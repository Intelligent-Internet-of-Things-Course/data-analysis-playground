# %% [markdown]
# # CSV Data Management

# %%
#Import and open the file
import csv
import os

data_folder = 'data' 
data_file = 'smarthome_power_consumption_small.csv'

file_path = os.path.join(data_folder,data_file)

#Read and iterate for each row
with open(file_path,newline='') as csvfile:
   csvreader = csv.reader(csvfile)
   for row in csvreader:
     print(row)
# Out:
# ['datetime', 'Global_active_power', 'Global_reactive_power', 'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3', 'sub_metering_4']
# ['2006-12-16 17:24:00', '4.216', '0.418', '234.84', '18.4', '0.0', '1.0', '17.0', '52.26667']
# ['2006-12-16 17:25:00', '5.36', '0.436', '233.63', '23.0', '0.0', '1.0', '16.0', '72.333336']
# ['2006-12-16 17:26:00', '5.374', '0.498', '233.29', '23.0', '0.0', '2.0', '17.0', '70.566666']
# ['2006-12-16 17:27:00', '5.388', '0.502', '233.74', '23.0', '0.0', '1.0', '17.0', '71.8']
# ['2006-12-16 17:28:00', '3.666', '0.528', '235.68', '15.8', '0.0', '1.0', '17.0', '43.1']
# ['2006-12-16 17:29:00', '3.52', '0.522', '235.02', '15.0', '0.0', '2.0', '17.0', '39.666668']
# ['2006-12-16 17:30:00', '3.702', '0.52', '235.09', '15.8', '0.0', '1.0', '17.0', '43.7']
# ['2006-12-16 17:31:00', '3.7', '0.52', '235.22', '15.8', '0.0', '1.0', '17.0', '43.666668']
# ...

# %% [markdown]
# # CSV with Pandas Module

# %%
import sys
# !{sys.executable} -m pip install pandas

import pandas as pd
# Out:
# ...
#   Using cached pandas-1.1.5-cp39-cp39-macosx_10_9_x86_64.whl (10.3 MB)
# ...
#   Using cached pytz-2020.4-py2.py3-none-any.whl (509 kB)
# ...
# WARNING: You are using pip version 20.2.4; however, version 20.3.1 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/2.2.9_1/libexec/bin/python -m pip install --upgrade pip' command.

# %%
csv_dataframe = pd.read_csv(file_path)
print(csv_dataframe)
# Out:
#                 datetime  Global_active_power  Global_reactive_power  Voltage  \
# 0    2006-12-16 17:24:00                4.216                  0.418   234.84
# 1    2006-12-16 17:25:00                5.360                  0.436   233.63
# 2    2006-12-16 17:26:00                5.374                  0.498   233.29
# 3    2006-12-16 17:27:00                5.388                  0.502   233.74
# 4    2006-12-16 17:28:00                3.666                  0.528   235.68
# ..                   ...                  ...                    ...      ...
# 323  2006-12-16 22:47:00                0.284                  0.000   242.04
# 324  2006-12-16 22:48:00                2.342                  0.060   239.89
# 325  2006-12-16 22:49:00                2.392                  0.000   239.91
# 326  2006-12-16 22:50:00                2.414                  0.000   240.02
# 327  2006-12-16 22:51:00                2.414                  0.000   239.97
#
# ...

# %% [markdown]
# # CSV with NumPy Module

# %%
#Import NumPy Module
import numpy as np

#Load only Numeric values in column 2 using NumPy module
array = np.loadtxt(file_path, skiprows=1, delimiter=',', usecols=(1))
print(array)
# Out:
# [4.216 5.36  5.374 5.388 3.666 3.52  3.702 3.7   3.668 3.662 4.448 5.412
#  5.224 5.268 4.054 3.384 3.27  3.43  3.266 3.728 5.894 7.706 7.026 5.174
#  4.474 3.248 3.236 3.228 3.258 3.178 2.72  3.758 4.342 4.512 4.058 2.472
#  2.79  2.624 2.772 3.74  4.928 6.052 6.752 6.474 6.308 4.464 3.396 3.09
#  3.73  2.308 2.388 4.598 4.524 4.202 4.472 2.852 2.928 2.94  2.934 2.926
#  3.452 4.87  4.868 4.866 3.176 2.92  2.93  2.912 2.608 2.714 3.538 6.072
#  4.536 4.408 2.912 2.326 2.264 2.27  2.258 2.188 2.978 4.2   4.204 4.218
#  2.786 2.54  2.496 2.336 2.322 2.448 4.298 4.23  4.23  3.924 4.218 4.224
#  4.07  3.612 3.458 3.434 3.366 3.404 3.382 3.616 3.476 3.394 3.4   3.414
#  3.432 3.418 3.392 3.394 3.394 3.406 3.42  3.418 3.422 3.332 3.316 3.334
#  3.262 3.476 3.62  3.61  3.646 3.614 3.408 3.388 3.372 3.37  3.342 3.284
#  3.276 3.382 3.418 3.396 3.406 3.406 3.392 3.378 3.368 3.35  3.352 3.364
#  3.38  3.404 3.378 3.388 3.376 3.254 3.214 3.202 3.202 3.212 3.206 3.214
# ...
